# %% [markdown]
# ### Introduction
# ### Create a model that can accurately predict whether a user belongs to the HCP(Healthcare Professional) category.

# %%
# !pip install shap
# Out:
# Requirement already satisfied: shap in c:\users\dell\anaconda3\lib\site-packages (0.45.1)
# Requirement already satisfied: cloudpickle in c:\users\dell\anaconda3\lib\site-packages (from shap) (2.0.0)
# Requirement already satisfied: slicer==0.0.8 in c:\users\dell\anaconda3\lib\site-packages (from shap) (0.0.8)
# Requirement already satisfied: scipy in c:\users\dell\anaconda3\lib\site-packages (from shap) (1.9.1)
# Requirement already satisfied: numpy in c:\users\dell\anaconda3\lib\site-packages (from shap) (1.21.5)
# Requirement already satisfied: tqdm>=4.27.0 in c:\users\dell\anaconda3\lib\site-packages (from shap) (4.64.1)
# Requirement already satisfied: numba in c:\users\dell\anaconda3\lib\site-packages (from shap) (0.55.1)
# Requirement already satisfied: pandas in c:\users\dell\anaconda3\lib\site-packages (from shap) (1.4.4)
# Requirement already satisfied: scikit-learn in c:\users\dell\anaconda3\lib\site-packages (from shap) (1.0.2)
# Requirement already satisfied: packaging>20.9 in c:\users\dell\anaconda3\lib\site-packages (from shap) (23.2)
# Requirement already satisfied: colorama in c:\users\dell\anaconda3\lib\site-packages (from tqdm>=4.27.0->shap) (0.4.6)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\users\dell\anaconda3\lib\site-packages (from numba->shap) (0.38.0)
# Requirement already satisfied: setuptools in c:\users\dell\anaconda3\lib\site-packages (from numba->shap) (63.4.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\anaconda3\lib\site-packages (from pandas->shap) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\dell\anaconda3\lib\site-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\dell\anaconda3\lib\site-packages (from scikit-learn->shap) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\dell\anaconda3\lib\site-packages (from scikit-learn->shap) (1.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\dell\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->shap) (1.16.0)

# %% [markdown]
# ### Import the necessary packages.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns # visualization
from matplotlib import pyplot as plt # visualization
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
import re
import copy
import random

from sklearn.preprocessing import LabelEncoder, StandardScaler, PowerTransformer

from sklearn.model_selection import  cross_val_score,KFold,train_test_split,ShuffleSplit,StratifiedKFold,learning_curve
from catboost import CatBoostClassifier,Pool,cv,monoforest
import optuna

from optuna.samplers import RandomSampler,TPESampler,MOTPESampler,CmaEsSampler
from sklearn.metrics import r2_score,confusion_matrix,ConfusionMatrixDisplay,roc_auc_score,accuracy_score

import math

import shap
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...

# %% [markdown]
# ### Import train and test dataset

# %%
train=pd.read_csv("E:\hcp\HCP_Train.csv", encoding='ISO-8859-1')
test=pd.read_csv("E:\hcp\HCP_Test.csv", encoding='ISO-8859-1')

# %% [markdown]
# ### Combine train and test data

# %%
train['data']='train'
test['data']='test'

# %%
full_data=pd.concat([train,test],axis=0)

# %% [markdown]
# ### Function for pre-process the data

# %%
def pre_process(df):
    #change column names to lowercase
    df=df.rename(columns={col:col.lower() for col in df.columns})
    #extract device information (windows, iphone, andriod, etc.)
    df['device_info']=df['useragent'].str.extract("([a-z|A-Z|0-9|\s|.|,]+;)")
    df['device_info']=df['device_info'].str.replace(";","")
    df['device_info']=df['device_info'].fillna("Windows NT 10.0")
    
    def device_brand_name(row):
        if re.match("Windows|X11",row):
            return "microsoft"
        elif re.match("Android",row):
            return 'andriod'
        elif re.match("Linux",row):
            return 'linux'
        elif re.match("Macintosh|iPad|iPod|iPhone",row):
            return 'apple'
        elif re.match("KHTML, like Gecko|compatible",row):
            return 'other'
    
        
    df['brand_name']=df['device_info'].apply(lambda x:device_brand_name(x))
    
    #extract browser information
    df['browser']=df['useragent'].apply(lambda x:"_".join(re.findall("(Mozilla|Chrome|Safari)",str(x))))
    #extract site information
    df['site_name']=df['url'].str.extract("https?://(www.|consumer.|.uat)?(\w+)(.com|.org)?")[1]
    #extract domain name
    df['domain_name']=df['url'].str.extract("(.com|.org)")
    #extract site prefix
    df['site_prefix']=df['url'].str.extract("https?://(www.|consumer.|.uat)?")
    df['site_prefix']= df['site_prefix'].fillna("none")
    #extract search infor from url
    df['search_info']=df['url'].str.extract("https?://(www.|consumer.|.uat)?(\w+)(.com|.org)?(.+)")[3]
    df['search_info']=df['search_info'].str.replace("[^\w\s]|home|articles|topics|slang|code|words|[0-9]|[…\u2026]+"," ")
    df['search_info']=df['search_info'].apply(lambda x:x.strip())
    df['search_info']=df['search_info'].apply(lambda x:" ".join(i for i in x.split() if len(i)>5 ))
    #fill missing value for column userplatformuid
    df['userplatformuid']=df['userplatformuid'].fillna("undefined")
    df['userplatformuid_len']=df['userplatformuid'].apply(lambda x: len(x))
    #replace keywords category keywords
    df['keywords']=df['keywords'].str.replace("covid-19","covid")
    
   
    #unique ip address count
    df["ip_user_count"]=df.groupby('bidrequestip')['bidrequestip'].transform('count')
    
    #groupby count of categorical column level
    for col in ['devicetype', 'userplatformuid', 'platformtype',
       'channeltype', 'keywords', 'device_info', 'brand_name', 'browser',
       'site_name', 'domain_name', 'site_prefix']:
        df[f"ip_{col}_count"]=df.groupby('bidrequestip')[col].transform('count')
    
    
    return df

# %% [markdown]
# ### Apply pre-process to combined data

# %%
full_data=pre_process(full_data)

# %% [markdown]
# ### Split train and test data from comined data.

# %%
train=full_data[full_data['data']=='train']
test=full_data[full_data['data']=='test']

# %% [markdown]
# ### Target column has null value remove the null value from the train data and split predictor and response column.

# %%
train1=train[train['is_hcp'].notnull()]

# %%
train1.head(2)
# Out:
#      id devicetype  platform_id   bidrequestip  \
# 0  1001    Desktop            2   170.173.0.22
# 1  1002    Desktop            2  65.216.253.25
#
#                         userplatformuid   usercity  userzipcode  \
# 0  6974dcaa-f932-480e-9fb5-c52e20e1393a   Portland      97206.0
# 1  c12f3f8f-8fcf-484a-90e1-1ac04db8cdcf  Arlington      22202.0
#
#                                            useragent            platformtype  \
# 0  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  Online Medical Journal
# 1  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...  Online Medical Journal
#
#   channeltype  ... ip_userplatformuid_count ip_platformtype_count  \
# 0     Website  ...                       34                    34
# 1     Website  ...                      728                   728
#
#   ip_channeltype_count  ip_keywords_count ip_device_info_count  \
# 0                   34                 34                   34
# 1                  728                728                  728
#
#   ip_brand_name_count ip_browser_count ip_site_name_count  \
# 0                  34               34                 34
# 1                 728              728                728
#
#   ip_domain_name_count ip_site_prefix_count
# 0                   34                   34
# 1                  728                  728
#
# [2 rows x 35 columns]

# %%
for i,col in enumerate(train.columns):
    print(f"{i}_{col}")
# Out:
# 0_id
# 1_devicetype
# 2_platform_id
# 3_bidrequestip
# 4_userplatformuid
# 5_usercity
# 6_userzipcode
# 7_useragent
# 8_platformtype
# 9_channeltype
# 10_url
# 11_keywords
# 12_taxonomy
# 13_is_hcp
# 14_data
# 15_device_info
# 16_brand_name
# 17_browser
# 18_site_name
# 19_domain_name
# 20_site_prefix
# 21_search_info
# 22_userplatformuid_len
# 23_ip_user_count
# 24_ip_devicetype_count
# 25_ip_userplatformuid_count
# 26_ip_platformtype_count
# 27_ip_channeltype_count
# 28_ip_keywords_count
# 29_ip_device_info_count
# 30_ip_brand_name_count
# 31_ip_browser_count
# 32_ip_site_name_count
# 33_ip_domain_name_count
# 34_ip_site_prefix_count

# %%
X=train1.iloc[:,np.r_[1,2,3,4,8,9,11,15,16,17,18,19,20,22:35]]
y=train1['is_hcp']

# %% [markdown]
# ### Split the train dataset to evaluate the model.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.3, 
                                                    random_state=42,
                                                   stratify=y
                                                   )

# %% [markdown]
# ### Store X_train and y_train features in new object.

# %%
X1=X_train
y1=y_train

# %% [markdown]
# ### Create catboost model and tune the hyperparameters by using optuna framework.

# %%
def objective(trial):
    skf = StratifiedKFold(n_splits=5,random_state=42,shuffle=True)
    for i, (train_index, test_index) in enumerate(skf.split(X1,y1)):
        X_train, X_valid = X1.iloc[train_index], X1.iloc[test_index]
        y_train, y_valid = y1.iloc[train_index], y1.iloc[test_index]
        param = {

            'l2_leaf_reg':trial.suggest_float('reg_lambda',1e-3, 1e-1, log=True),
            'learning_rate': trial.suggest_float('learning_rate', 1e-3, 1e-1, log=True),
            'n_estimators': trial.suggest_int('n_estimators',50,1000),
            'max_depth': trial.suggest_int('max_depth', 1,10),
            'random_state': trial.suggest_categorical('random_state', [100,200,300,400,500]),
           "colsample_bylevel": trial.suggest_float("colsample_bylevel", 0.01,0.1,log=True),
            "boosting_type": trial.suggest_categorical("boosting_type", ["Ordered", 
                                                                         #"Plain"
                                                                        ]),
            #"auto_class_weights": trial.suggest_categorical("auto_class_weights", ["Balanced","SqrtBalanced"]),
            "min_data_in_leaf": trial.suggest_int("min_data_in_leaf",1, 100),
           'random_strength': trial.suggest_uniform('random_strength', 0.1, 1.0),
            'od_type':trial.suggest_categorical("od_type", ["IncToDec", "Iter"]),
            'od_wait':trial.suggest_int("od_wait", 1, 200),
           # "grow_policy": trial.suggest_categorical("grow_policy", ["SymmetricTree","Depthwise",
                                                                     #   "Lossguide"]),
            "bootstrap_type": trial.suggest_categorical("bootstrap_type", [#"Bayesian", 
                                                                           "Bernoulli",
                            # "MVS"
                              ]
            ),
            }
        if param["bootstrap_type"] == "Bayesian":
            param["bagging_temperature"] = trial.suggest_float("bagging_temperature", 0, 10)
        elif param["bootstrap_type"] == "Bernoulli":
            param["subsample"] = trial.suggest_float("subsample", 0.1, 1)

        cat_clf = CatBoostClassifier(#early_stopping_rounds=100,
                                     eval_metric="Accuracy",#grow_policy='Lossguide',
                                   logging_level="Silent",#ask_type='GPU',
                                  **param)
      #  pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
        cat_clf.fit(X_train, y_train,eval_set=[(X_valid,y_valid)],
                    cat_features=X.select_dtypes(include='object').columns.values ,
                   # callbacks=[pruning_callback]
                   )
        #pruning_callback.check_pruned()

        preds = cat_clf.predict(X_test)
        #preds_prob = cat_clf.predict_proba(X_test)[:,1]
        #accuracy_roc = roc_auc_score(y_test, preds_prob)
        accuracy = accuracy_score(y_test, preds)
        return accuracy



if __name__ == "__main__":
    study = optuna.create_study(direction='maximize',sampler=MOTPESampler(),
           pruner=optuna.pruners.SuccessiveHalvingPruner())
    study.optimize(objective, n_trials=100)
    print('Number of finished trials:', len(study.trials))
    print('Best trial:', study.best_trial.params)
# Out:
# [I 2024-05-26 16:56:48,122] A new study created in memory with name: no-name-17de19b9-215c-4bc6-8cbb-5c93647aa96a
# [I 2024-05-26 16:56:50,499] Trial 0 finished with value: 0.7000087768058278 and parameters: {'reg_lambda': 0.031414630199198636, 'learning_rate': 0.05321459623960325, 'n_estimators': 420, 'max_depth': 4, 'random_state': 200, 'colsample_bylevel': 0.010625640728498547, 'boosting_type': 'Ordered', 'min_data_in_leaf': 22, 'random_strength': 0.793825419974367, 'od_type': 'Iter', 'od_wait': 2, 'bootstrap_type': 'Bernoulli', 'subsample': 0.12799644848280725}. Best is trial 0 with value: 0.7000087768058278.
# [I 2024-05-26 16:57:59,227] Trial 1 finished with value: 0.9964307656300284 and parameters: {'reg_lambda': 0.0764581300029008, 'learning_rate': 0.0036117265157728736, 'n_estimators': 593, 'max_depth': 3, 'random_state': 500, 'colsample_bylevel': 0.06273886086329358, 'boosting_type': 'Ordered', 'min_data_in_leaf': 31, 'random_strength': 0.11200485944153504, 'od_type': 'IncToDec', 'od_wait': 136, 'bootstrap_type': 'Bernoulli', 'subsample': 0.9932329717900338}. Best is trial 1 with value: 0.9964307656300284.
# [I 2024-05-26 16:58:25,835] Trial 2 finished with value: 0.9961382054357684 and parameters: {'reg_lambda': 0.0056019378774985, 'learning_rate': 0.07702539220349877, 'n_estimators': 223, 'max_depth': 2, 'random_state': 300, 'colsample_bylevel': 0.07870291541624741, 'boosting_type': 'Ordered', 'min_data_in_leaf': 13, 'random_strength': 0.5446234706478594, 'od_type': 'Iter', 'od_wait': 150, 'bootstrap_type': 'Bernoulli', 'subsample': 0.40346662924480203}. Best is trial 1 with value: 0.9964307656300284.
# [I 2024-05-26 17:00:22,498] Trial 3 finished with value: 0.9963137415523244 and parameters: {'reg_lambda': 0.005145054932714498, 'learning_rate': 0.0046119684781127795, 'n_estimators': 809, 'max_depth': 4, 'random_state': 500, 'colsample_bylevel': 0.0620853731168421, 'boosting_type': 'Ordered', 'min_data_in_leaf': 99, 'random_strength': 0.8552246727453643, 'od_type': 'IncToDec', 'od_wait': 69, 'bootstrap_type': 'Bernoulli', 'subsample': 0.2229526154262731}. Best is trial 1 with value: 0.9964307656300284.
# [I 2024-05-26 17:01:26,165] Trial 4 finished with value: 0.9964307656300284 and parameters: {'reg_lambda': 0.0010512300973488846, 'learning_rate': 0.009436351487486798, 'n_estimators': 485, 'max_depth': 5, 'random_state': 500, 'colsample_bylevel': 0.05226577750728792, 'boosting_type': 'Ordered', 'min_data_in_leaf': 30, 'random_strength': 0.9539490176808174, 'od_type': 'IncToDec', 'od_wait': 157, 'bootstrap_type': 'Bernoulli', 'subsample': 0.4594280558437003}. Best is trial 1 with value: 0.9964307656300284.
 'bootstrap_type': 'Bernoulli', 'subsample': 0.5906745954956695}. Best is trial 7 with value: 0.9967233258242884.
# [I 2024-05-26 17:07:41,975] Trial 11 finished with value: 0.9849624060150376 and parameters: {'reg_lambda': 0.003347236227099331, 'learning_rate': 0.0010551349631389905, 'n_estimators': 718, 'max_depth': 8, 'random_state': 300, 'colsample_bylevel': 0.019789834632706962, 'boosting_type': 'Ordered', 'min_data_in_leaf': 50, 'random_strength': 0.557903473175486, 'od_type': 'Iter', 'od_wait': 67, 'bootstrap_type': 'Bernoulli', 'subsample': 0.2980084792796334}. Best is trial 7 with value: 0.9967233258242884.
# [I 2024-05-26 17:07:44,277] Trial 12 finished with value: 0.7064743570989731 and parameters: {'reg_lambda': 0.002760484030023786, 'learning_rate': 0.030787691476565106, 'n_estimators': 668, 'max_depth': 7, 'random_state': 100, 'colsample_bylevel': 0.013752162807262542, 'boosting_type': 'Ordered', 'min_data_in_leaf': 54, 'random_strength': 0.5341248476615146, 'od_type': 'Iter', 'od_wait': 2, 'bootstrap_type': 'Bernoulli', 'subsample': 0.5560641029137865}. Best is trial 7 with value: 0.9967233258242884.
# [I 2024-05-26 17:08:30,086] Trial 13 finished with value: 0.9965477897077324 and parameters: {'reg_lambda': 0.07693019122678968, 'learning_rate': 0.032075581576353374, 'n_estimators': 317, 'max_depth': 10, 'random_state': 200, 'colsample_bylevel': 0.027955977076189468, 'boosting_type': 'Ordered', 'min_data_in_leaf': 42, 'random_strength': 0.36858833588722173, 'od_type': 'IncToDec', 'od_wait': 190, 'bootstrap_type': 'Bernoulli', 'subsample': 0.12083220109561604}. Best is trial 7 with value: 0.9967233258242884.
# [I 2024-05-26 17:08:44,569] Trial 14 finished with value: 0.9962552295134725 and parameters: {'reg_lambda': 0.038330060502389345, 'learning_rate': 0.09848755216253278, 'n_estimators': 85, 'max_depth': 7, 'random_state': 300, 'colsample_bylevel': 0.09538103974810416, 'boosting_type': 'Ordered', 'min_data_in_leaf': 3, 'random_strength': 0.6456270206017394, 'od_type': 'Iter', 'od_wait': 90, 'bootstrap_type': 'Bernoulli', 'subsample': 0.9713454781843848}. Best is trial 7 with value: 0.9967233258242884.
# [I 2024-05-26 17:08:51,330] Trial 15 finished with value: 0.9917205465024429 and parameters: {'reg_lambda': 0.010729545054393847, 'learning_rate': 0.0036461224511666395, 'n_estimators': 367, 'max_depth': 7, 'random_state': 300, 'colsample_bylevel': 0.04169167444469885, 'boosting_type': 'Ordered', 'min_data_in_leaf': 19, 'random_strength': 0.9982045132055902, 'od_type': 'Iter', 'od_wait': 32, 'bootstrap_type': 'Bernoulli', 'subsample': 0.4734505163132404}. Best is trial 7 with value: 0.9967233258242884.
# [I 2024-05-26 17:09:55,809] Trial 16 finished with value: 0.9113542611392293 and parameters: {'reg_lambda': 0.04544494101695409, 'learning_rate': 0.0010808309827526892, 'n_estimators': 654, 'max_depth': 6, 'random_state': 200, 'colsample_bylevel': 0.016469231805815675, 'boosting_type': 'Ordered', 'min_data_in_leaf': 39, 'random_strength': 0.3951161419633209, 'od_type': 'IncToDec', 'od_wait': 107, 'bootstrap_type': 'Bernoulli', 'subsample': 0.25697620073950067}. Best is trial 7 with value: 0.9967233258242884.
# [I 2024-05-26 17:10:37,423] Trial 17 finished with value: 0.9965477897077324 and parameters: {'reg_lambda': 0.01849065088948962, 'learning_rate': 0.016939323722259054, 'n_estimators': 777, 'max_depth': 9, 'random_state': 100, 'colsample_bylevel': 0.028391043319704757, 'boosting_type': 'Ordered', 'min_data_in_leaf': 12, 'random_strength': 0.12098774464733786, 'od_type': 'Iter', 'od_wait': 125, 'bootstrap_type': 'Bernoulli', 'subsample': 0.
 'bootstrap_type': 'Bernoulli', 'subsample': 0.5375204823191124}. Best is trial 48 with value: 0.9969573739796963.
# [I 2024-05-26 19:49:16,133] Trial 99 finished with value: 0.9965185336883063 and parameters: {'reg_lambda': 0.003109326516992808, 'learning_rate': 0.07414990601041227, 'n_estimators': 523, 'max_depth': 8, 'random_state': 300, 'colsample_bylevel': 0.031016937544437174, 'boosting_type': 'Ordered', 'min_data_in_leaf': 69, 'random_strength': 0.35142008266255675, 'od_type': 'IncToDec', 'od_wait': 104, 'bootstrap_type': 'Bernoulli', 'subsample': 0.5761404419818309}. Best is trial 48 with value: 0.9969573739796963.
# Number of finished trials: 100
# Best trial: {'reg_lambda': 0.0020167870779301683, 'learning_rate': 0.07899295393423905, 'n_estimators': 338, 'max_depth': 6, 'random_state': 100, 'colsample_bylevel': 0.06917651225109324, 'boosting_type': 'Ordered', 'min_data_in_leaf': 51, 'random_strength': 0.23494141046341255, 'od_type': 'IncToDec', 'od_wait': 84, 'bootstrap_type': 'Bernoulli', 'subsample': 0.8119327499750459}

# %% [markdown]
# ### The best score and parameters.

# %%
study.best_params
# Out:
# {'reg_lambda': 0.0020167870779301683,
#  'learning_rate': 0.07899295393423905,
#  'n_estimators': 338,
#  'max_depth': 6,
#  'random_state': 100,
#  'colsample_bylevel': 0.06917651225109324,
#  'boosting_type': 'Ordered',
#  'min_data_in_leaf': 51,
#  'random_strength': 0.23494141046341255,
#  'od_type': 'IncToDec',
#  'od_wait': 84,
#  'bootstrap_type': 'Bernoulli',
#  'subsample': 0.8119327499750459}

# %%
#best score
study.best_value
param_cat=study.best_params
# Out:
# 0.9969573739796963

# %% [markdown]
# ### Fit catboost classifier with tuned parameters.

# %%
# %matplotlib inline

# %%
eval_cat_clf = CatBoostClassifier(#early_stopping_rounds=30,
    eval_metric="Accuracy",logging_level="Silent", **param_cat)
eval_cat_clf.fit(X_train, y_train,eval_set=(X_test,y_test), 
            cat_features=X_train.select_dtypes(include='object').columns.values)

# %%
val_predict=eval_cat_clf.predict(X_test)
print(f"Validation Data Accuracy:{accuracy_score(y_test,val_predict)}")
# Out:
# Validation Data Accuracy:0.9978935666013282

# %% [markdown]
# ### Validation data Confusion matrix

# %%
def confusion_matrix_plot(y_true,predicted):
    fig, (ax1) = plt.subplots(nrows=1, figsize=(8, 5))
    conf=confusion_matrix(y_true,predicted)
    conf = conf.astype('float') / conf.sum(axis=1)[:, np.newaxis]
    sns.heatmap(conf, annot=True,  cmap="Blues",fmt=".2%")
    ax1.set_title("Confusion Matrix\n")
    ax1.set_xlabel("Predicted")
    ax1.set_ylabel("True")
    ax1.yaxis.set_ticklabels([0,1],rotation=0)

# %%
confusion_matrix_plot(y_test,val_predict)

# %%
cat_clf = CatBoostClassifier(#early_stopping_rounds=30,
    eval_metric="Accuracy", **param_cat)
cat_clf.fit(X,y,#X_train, y_train,eval_set=(X_test,y_test), 
            cat_features=X.select_dtypes(include='object').columns.values)
# Out:
# 0:	learn: 0.9865187	total: 194ms	remaining: 1m 5s
# 1:	learn: 0.9865187	total: 347ms	remaining: 58.1s
# 2:	learn: 0.9865187	total: 507ms	remaining: 56.5s
# 3:	learn: 0.9865187	total: 650ms	remaining: 54.1s
# 4:	learn: 0.9869225	total: 1.84s	remaining: 2m 2s
# 5:	learn: 0.9876071	total: 2.23s	remaining: 2m 3s
# 314:	learn: 0.9957257	total: 4m 9s	remaining: 17.4s
# 315:	learn: 0.9957081	total: 4m 10s	remaining: 16.7s
# 316:	learn: 0.9957520	total: 4m 11s	remaining: 15.9s
# 317:	learn: 0.9957608	total: 4m 12s	remaining: 15.1s
# 318:	learn: 0.9957608	total: 4m 13s	remaining: 14.3s
# 319:	learn: 0.9957696	total: 4m 14s	remaining: 13.5s
# 320:	learn: 0.9957959	total: 4m 15s	remaining: 12.8s
# 321:	learn: 0.9957959	total: 4m 16s	remaining: 11.9s
# 322:	learn: 0.9957696	total: 4m 17s	remaining: 11.2s
# 323:	learn: 0.9957696	total: 4m 18s	remaining: 10.4s
# 324:	learn: 0.9957871	total: 4m 19s	remaining: 9.6s
# 325:	learn: 0.9957871	total: 4m 20s	remaining: 8.78s
# 326:	learn: 0.9957959	total: 4m 21s	remaining: 7.99s
# 327:	learn: 0.9958310	total: 4m 22s	remaining: 7.2s
# 328:	learn: 0.9958222	total: 4m 23s	remaining: 6.42s
# 329:	learn: 0.9958222	total: 4m 25s	remaining: 5.63s
# 330:	learn: 0.9958398	total: 4m 26s	remaining: 4.83s
# 331:	learn: 0.9958398	total: 4m 27s	remaining: 4.03s
# 332:	learn: 0.9958573	total: 4m 29s	remaining: 3.23s
# 333:	learn: 0.9958837	total: 4m 30s	remaining: 2.43s
# 334:	learn: 0.9958837	total: 4m 31s	remaining: 1.62s
# 335:	learn: 0.9959275	total: 4m 33s	remaining: 813ms
# 336:	learn: 0.9959363	total: 4m 34s	remaining: 0us

# %% [markdown]
# ### Feature importances Catboost model(default interpretation).

# %%
def feature_imp_plot(df,feat_imp_score,title="" ):
    _=plt.figure(figsize=(12,6))
    feat_importance=pd.DataFrame({'columns':df.columns,'score':feat_imp_score})
    feat_importance=feat_importance.sort_values('score',ascending=False)
    _=sns.barplot(data=feat_importance.nlargest(10,'score'),x='score',y='columns')
    plt.title(f"{title}",fontsize=16)

# %%
feature_imp_plot(X,cat_clf.get_feature_importance(),"Catboost Model Top Feature Importances")

# %% [markdown]
# ### Interpret model with SHAP

# %%
explainer = shap.TreeExplainer(cat_clf)
shap_values = explainer.shap_values(X, y)

# %% [markdown]
# ### Feature importances plot

# %%
shap.summary_plot(shap_values, X, plot_type="bar",
                  max_display=10)

# %% [markdown]
# ### Top features impact the model

# %%
shap.summary_plot(shap_values, X)

# %% [markdown]
# ### Overall Train and Validation Accuracy

# %%
def overall_logloss(model):
    fig=plt.figure(figsize=(8,5))
    _=plt.plot(model.evals_result_['learn']['Accuracy'],marker=".",label="Train")
    _=plt.plot(model.evals_result_['validation']['Accuracy'],marker=".",label="Validation")
    _=plt.ylabel("Accuracy",fontsize=15)
    _=plt.xlabel("Iterations",fontsize=15)
    _=plt.title("Catboost Model Overall Train and Validation Accuracy \n",fontsize=18)
    plt.legend()
    plt.show()

# %%
overall_logloss(eval_cat_clf)

# %% [markdown]
# ### Predict the test data

# %%
test_pre=cat_clf.predict(test.loc[:,X.columns])
